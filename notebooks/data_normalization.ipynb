# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
df= pd.read_csv('/Users/marina/Desktop/final_project/data/cleaned/okcupid_preprocessed.csv')
#data/raw/okcupid_profiles .csv

# %%
df.head()
# Out:
#    profile_id  age  status sex orientation body_type            diet  \
# 0        1000   22  single   m    straight     curvy        anything
# 1        1001   35  single   m    straight   average           other
# 2        1002   23  single   m    straight    skinny      vegetarian
# 3        1003   29  single   m    straight       fit  rather not say
# 4        1004   29  single   m    straight   average        anything
#
#       drinks           drugs        education  ...  \
# 0  sometimes           never  College or more  ...
# 1      often       sometimes  College or more  ...
# 2  sometimes  rather not say  College or more  ...
# 3  sometimes           never  College or more  ...
# 4  sometimes  rather not say  College or more  ...
#
#                                             my_goals  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2          reading things written by old dead people
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47150 entries, 0 to 47149
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   profile_id      47150 non-null  int64
#  1   age             47150 non-null  int64
#  2   status          47150 non-null  object
#  3   sex             47150 non-null  object
#  4   orientation     47150 non-null  object
#  5   body_type       47150 non-null  object
#  6   diet            47150 non-null  object
#  7   drinks          47150 non-null  object
#  8   drugs           47150 non-null  object
#  9   education       47150 non-null  object
#  10  ethnicity       47150 non-null  object
#  11  height          47150 non-null  float64
#  12  income          47150 non-null  int64
#  13  job             47150 non-null  object
#  14  last_online     47150 non-null  object
#  15  offspring       47150 non-null  object
#  16  pets            47150 non-null  object
# ...

# %%
#job,location

# %% [markdown]
# # Job

# %%
df['job'].unique()
# Out:
# array(['transportation', 'hospitality', 'student', 'arts', 'it',
#        'finance', 'marketing', 'other', 'healthcare', 'media',
#        'science and tech', 'management', 'education', 'admin',
#        'construction', 'politics', 'legal', 'unemployed', 'military',
#        'retired'], dtype=object)

# %%
df['about_me'].unique()
# Out:
# array(["about me:  i would love to think that i was some some kind of intellectual: either the dumbest smart guy, or the smartest dumb guy. can't say i can tell the difference. i love to talk about ideas and concepts. i forge odd metaphors instead of reciting cliches. like the simularities between a friend of mine's house and an underwater salt mine. my favorite word is salt by the way (weird choice i know). to me most things in life are better as metaphors. i seek to make myself a little better everyday, in some productively lazy way. got tired of tying my shoes. considered hiring a five year old, but would probably have to tie both of our shoes... decided to only wear leather shoes dress shoes.  about you:  you love to have really serious, really deep conversations about really silly stuff. you have to be willing to snap me out of a light hearted rant with a kiss. you don't have to be funny, but you have to be able to make me laugh. you should be able to bend spoons with your mind,
# ...

# %%
#Function to count the number of values in each cell of a specific column

def count_values_per_row(cell, delimiter=','):
    if pd.isna(cell):
        return 0
    return len(cell.split(delimiter))

# Apply the function to the 'ethnicity' column
df['ethnicity_count'] = df['ethnicity'].apply(count_values_per_row)

# Show the result
print(df)
# Out:
#        profile_id  age  status sex orientation body_type            diet  \
# 0            1000   22  single   m    straight     curvy        anything
# 1            1001   35  single   m    straight   average           other
# 2            1002   23  single   m    straight    skinny      vegetarian
# 3            1003   29  single   m    straight       fit  rather not say
# 4            1004   29  single   m    straight   average        anything
# ...           ...  ...     ...  ..         ...       ...             ...
# 47145       48216   32  single   m    bisexual    skinny        anything
# 47146       48217   24  single   m    straight       fit        anything
# 47147       48218   42  single   m    straight   average        anything
# 47148       48219   27  single   m    straight       fit        anything
# 47149       48220   39  single   m         gay   average  rather not say
#
#           drinks           drugs        education  ...  \
# ...

# %%
df['ethnicity'].unique()
# Out:
# array(['asian', 'white', 'hispanic', 'rather not say', 'other', 'black',
#        'indian'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47150 entries, 0 to 47149
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile_id       47150 non-null  int64
#  1   age              47150 non-null  int64
#  2   status           47150 non-null  object
#  3   sex              47150 non-null  object
#  4   orientation      47150 non-null  object
#  5   body_type        47150 non-null  object
#  6   diet             47150 non-null  object
#  7   drinks           47150 non-null  object
#  8   drugs            47150 non-null  object
#  9   education        47150 non-null  object
#  10  ethnicity        47150 non-null  object
#  11  height           47150 non-null  float64
#  12  income           47150 non-null  int64
#  13  job              47150 non-null  object
#  14  last_online      47150 non-null  object
#  15  offspring        47150 non-null  object
# ...

# %% [markdown]
# # about me

# %%
#about_ me

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=30)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['about_me'])

# Convert the result to a DataFrame
keywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
keywords_df.info()

#travel, family, friends, fun, passionate, laugh, work, love, enjoy, new
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47150 entries, 0 to 47149
# Data columns (total 30 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   bay      47150 non-null  int64
#  1   don      47150 non-null  int64
#  2   enjoy    47150 non-null  int64
#  3   friends  47150 non-null  int64
#  4   fun      47150 non-null  int64
#  5   going    47150 non-null  int64
#  6   good     47150 non-null  int64
#  7   great    47150 non-null  int64
#  8   just     47150 non-null  int64
#  9   know     47150 non-null  int64
#  10  life     47150 non-null  int64
#  11  like     47150 non-null  int64
#  12  live     47150 non-null  int64
#  13  looking  47150 non-null  int64
#  14  love     47150 non-null  int64
#  15  make     47150 non-null  int64
#  16  music    47150 non-null  int64
#  17  new      47150 non-null  int64
#  18  people   47150 non-null  int64
#  19  person   47150 non-null  int64
#  20  pretty   47150 non-null  int64
# ...

# %% [markdown]
# # my_goals

# %%
#my_goals 

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=20)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['my_goals'])

# Convert the result to a DataFrame
gkeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
gkeywords_df.info()

#life, work, school, work, new, people, job, friends, people, time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   currently  47221 non-null  int64
#  1   day        47221 non-null  int64
#  2   doing      47221 non-null  int64
#  3   friends    47221 non-null  int64
#  4   going      47221 non-null  int64
#  5   job        47221 non-null  int64
#  6   just       47221 non-null  int64
#  7   life       47221 non-null  int64
#  8   like       47221 non-null  int64
#  9   love       47221 non-null  int64
#  10  new        47221 non-null  int64
#  11  people     47221 non-null  int64
#  12  say        47221 non-null  int64
#  13  school     47221 non-null  int64
#  14  things     47221 non-null  int64
#  15  time       47221 non-null  int64
#  16  trying     47221 non-null  int64
#  17  ve         47221 non-null  int64
#  18  work       47221 non-null  int64
#  19  working    47221 non-null  int64
# ...

# %% [markdown]
# # my talent

# %%
#my_goals 

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=30)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['my_talent'])

# Convert the result to a DataFrame
tkeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
tkeywords_df.info()

#life, people, love, cooking, friends, laugh, playing, fun, dancing, listening
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 30 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cooking    47221 non-null  int64
#  1   dancing    47221 non-null  int64
#  2   finding    47221 non-null  int64
#  3   friends    47221 non-null  int64
#  4   fun        47221 non-null  int64
#  5   getting    47221 non-null  int64
#  6   good       47221 non-null  int64
#  7   great      47221 non-null  int64
#  8   having     47221 non-null  int64
#  9   just       47221 non-null  int64
#  10  know       47221 non-null  int64
#  11  laugh      47221 non-null  int64
#  12  laughing   47221 non-null  int64
#  13  life       47221 non-null  int64
#  14  like       47221 non-null  int64
#  15  listening  47221 non-null  int64
#  16  love       47221 non-null  int64
#  17  make       47221 non-null  int64
#  18  making     47221 non-null  int64
#  19  new        47221 non-null  int64
# ...

# %% [markdown]
# # my_highlights

# %%
#my_highlights

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=30)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['my_highlights'])

# Convert the result to a DataFrame
hkeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
hkeywords_df.info()

# hair, humor, eyes, laugh, smile, tall, personality, people, pretty, height
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   big          47221 non-null  int64
#  1   blue         47221 non-null  int64
#  2   don          47221 non-null  int64
#  3   eyes         47221 non-null  int64
#  4   good         47221 non-null  int64
#  5   hair         47221 non-null  int64
#  6   height       47221 non-null  int64
#  7   humor        47221 non-null  int64
#  8   just         47221 non-null  int64
#  9   know         47221 non-null  int64
#  10  laugh        47221 non-null  int64
#  11  like         47221 non-null  int64
#  12  look         47221 non-null  int64
#  13  lot          47221 non-null  int64
#  14  maybe        47221 non-null  int64
#  15  notice       47221 non-null  int64
#  16  people       47221 non-null  int64
#  17  personality  47221 non-null  int64
#  18  pretty       47221 non-null  int64
# ...

# %% [markdown]
# # my_favourites

# %%
#my_highlights

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=50)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['my_favorites'])

# Convert the result to a DataFrame
fkeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
fkeywords_df.info()

# books, music, movie, shows, tv, eat, food, read, life, family
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 50 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   american   47221 non-null  int64
#  1   big        47221 non-null  int64
#  2   black      47221 non-null  int64
#  3   book       47221 non-null  int64
#  4   books      47221 non-null  int64
#  5   don        47221 non-null  int64
#  6   eat        47221 non-null  int64
#  7   enjoy      47221 non-null  int64
#  8   family     47221 non-null  int64
#  9   favorite   47221 non-null  int64
#  10  favorites  47221 non-null  int64
#  11  fiction    47221 non-null  int64
#  12  food       47221 non-null  int64
#  13  good       47221 non-null  int64
#  14  great      47221 non-null  int64
#  15  house      47221 non-null  int64
#  16  indian     47221 non-null  int64
#  17  italian    47221 non-null  int64
#  18  just       47221 non-null  int64
#  19  life       47221 non-null  int64
# ...

# %% [markdown]
# #  my needs

# %%
#my_highlights

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=20)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['my_needs'])

# Convert the result to a DataFrame
nkeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
nkeywords_df.info()

# books, music, internet, coffee, friends , laughter, phone, family, love, food
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   books     47221 non-null  int64
#  1   coffee    47221 non-null  int64
#  2   computer  47221 non-null  int64
#  3   family    47221 non-null  int64
#  4   food      47221 non-null  int64
#  5   friends   47221 non-null  int64
#  6   good      47221 non-null  int64
#  7   internet  47221 non-null  int64
#  8   iphone    47221 non-null  int64
#  9   laughter  47221 non-null  int64
#  10  life      47221 non-null  int64
#  11  like      47221 non-null  int64
#  12  love      47221 non-null  int64
#  13  music     47221 non-null  int64
#  14  people    47221 non-null  int64
#  15  phone     47221 non-null  int64
#  16  say       47221 non-null  int64
#  17  things    47221 non-null  int64
#  18  time      47221 non-null  int64
#  19  water     47221 non-null  int64
# dtypes: int64(20)
# ...

# %% [markdown]
# # think about

# %%
#my_highlights

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=30)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['think_about'])

# Convert the result to a DataFrame
takeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
takeywords_df.info()

# friends, future, work, love, people, time, travel, world, music, family
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 30 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   better    47221 non-null  int64
#  1   day       47221 non-null  int64
#  2   doing     47221 non-null  int64
#  3   don       47221 non-null  int64
#  4   family    47221 non-null  int64
#  5   friends   47221 non-null  int64
#  6   future    47221 non-null  int64
#  7   going     47221 non-null  int64
#  8   good      47221 non-null  int64
#  9   just      47221 non-null  int64
#  10  life      47221 non-null  int64
#  11  like      47221 non-null  int64
#  12  lot       47221 non-null  int64
#  13  love      47221 non-null  int64
#  14  make      47221 non-null  int64
#  15  music     47221 non-null  int64
#  16  new       47221 non-null  int64
#  17  people    47221 non-null  int64
#  18  really    47221 non-null  int64
#  19  say       47221 non-null  int64
# ...

# %% [markdown]
# # typical friday

# %%
#my_highlights

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=30)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['typical_friday'])

# Convert the result to a DataFrame
tykeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
tykeywords_df.info()

# movie, work, bar, dancing, dinner, friends, hanging, music, relaxing, playing

#typical_friday  47221 non-null  object 
# 30  my_secret       47221 non-null  object 
# 31  message_if
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 30 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   bar       47221 non-null  int64
#  1   dancing   47221 non-null  int64
#  2   dinner    47221 non-null  int64
#  3   doing     47221 non-null  int64
#  4   drinks    47221 non-null  int64
#  5   friday    47221 non-null  int64
#  6   friends   47221 non-null  int64
#  7   going     47221 non-null  int64
#  8   good      47221 non-null  int64
#  9   hanging   47221 non-null  int64
#  10  having    47221 non-null  int64
#  11  home      47221 non-null  int64
#  12  just      47221 non-null  int64
#  13  like      47221 non-null  int64
#  14  movie     47221 non-null  int64
#  15  movies    47221 non-null  int64
#  16  music     47221 non-null  int64
#  17  new       47221 non-null  int64
#  18  night     47221 non-null  int64
#  19  playing   47221 non-null  int64
# ...

# %% [markdown]
# # my secret

# %%
#my_highlights

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=40)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['my_secret'])

# Convert the result to a DataFrame
sekeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
sekeywords_df.info()

# open, think, private, love, people, admit, ask , tell, love, want

#typical_friday  47221 non-null  object 
# 30  my_secret       47221 non-null  object 
# 31  message_if
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 40 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   actually  47221 non-null  int64
#  1   admit     47221 non-null  int64
#  2   ask       47221 non-null  int64
#  3   book      47221 non-null  int64
#  4   dating    47221 non-null  int64
#  5   don       47221 non-null  int64
#  6   feel      47221 non-null  int64
#  7   friends   47221 non-null  int64
#  8   going     47221 non-null  int64
#  9   good      47221 non-null  int64
#  10  got       47221 non-null  int64
#  11  just      47221 non-null  int64
#  12  know      47221 non-null  int64
#  13  life      47221 non-null  int64
#  14  like      47221 non-null  int64
#  15  little    47221 non-null  int64
#  16  ll        47221 non-null  int64
#  17  lot       47221 non-null  int64
#  18  love      47221 non-null  int64
#  19  make      47221 non-null  int64
# ...

# %% [markdown]
# # message_if

# %%
#my_highlights

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the CountVectorizer
vectorizer = CountVectorizer(stop_words='english', max_features=40)

# Fit and transform the 'about_me' column
X = vectorizer.fit_transform(df['message_if'])

# Convert the result to a DataFrame
sekeywords_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
sekeywords_df.info()

# love, fun, people, meet, enjoy, humor, friends, meet, talk, love

#typical_friday  47221 non-null  object 
# 30  my_secret       47221 non-null  object 
# 31  message_if
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47221 entries, 0 to 47220
# Data columns (total 40 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   conversation  47221 non-null  int64
#  1   don           47221 non-null  int64
#  2   enjoy         47221 non-null  int64
#  3   feel          47221 non-null  int64
#  4   friends       47221 non-null  int64
#  5   fun           47221 non-null  int64
#  6   going         47221 non-null  int64
#  7   good          47221 non-null  int64
#  8   great         47221 non-null  int64
#  9   guy           47221 non-null  int64
#  10  humor         47221 non-null  int64
#  11  interested    47221 non-null  int64
#  12  interesting   47221 non-null  int64
#  13  just          47221 non-null  int64
#  14  kind          47221 non-null  int64
#  15  know          47221 non-null  int64
#  16  laugh         47221 non-null  int64
#  17  life          47221 non-null  int64
# ...

# %%
# after analizing the 10 columns im creating 20 binary columns that summarize 
# relevant aspects for each profile
import pandas as pd
import re

# Manually defined keywords
keywords = ['love', 'fun', 'cooking', 'music', 'read', 'friends', 'work', 'travel', 'humor', 'movie', 'laugh', 'new', 'personality','future','people', 'smile','talk','life','tv','play']
# Columns to check
columns_to_check = ['about_me', 'my_goals', 'my_talent', 'my_highlights', 'my_favorites' , 'my_needs', 'think_about','typical_friday', 'my_secret', 'message_if']  

# Function to create binary columns
def keyword_presence(text, keyword):
    pattern = re.compile(r'\b' + re.escape(keyword) + r'\w*\b', re.IGNORECASE)
    return 1 if pattern.search(text) else 0

# Create binary columns for each keyword
for keyword in keywords:
    df[keyword] = df[columns_to_check].apply(lambda row: any(keyword_presence(str(cell), keyword) for cell in row), axis=1)

# Display the resulting DataFrame
print(df)

#travel, family, friends, fun, passionate, laugh, work, love, enjoy, new
#life, work, school, work, new, people, job, friends, people, time
#life, people, love, cooking, friends, laugh, playing, fun, dancing, listening
# hair, humor, eyes, laugh, smile, tall, personality, people, pretty, height
# books, music, movie, shows, tv, eat, food, read, life, family
# books, music, internet, coffee, friends , laughter, phone, family, love, food
# friends, future, work, love, people, time, travel, world, music, family
# movie, work, bar, dancing, dinner, friends, hanging, music, relaxing, playing
# open, think, private, love, people, admit, ask , tell, love, want
# love, fun, people, meet, enjoy, humor, friends, meet, talk, love
# Out:
#        profile_id  age  status sex orientation body_type            diet  \
# 0            1000   22  single   m    straight     curvy        anything
# 1            1001   35  single   m    straight   average           other
# 2            1002   23  single   m    straight    skinny      vegetarian
# 3            1003   29  single   m    straight       fit  rather not say
# 4            1004   29  single   m    straight   average        anything
# ...           ...  ...     ...  ..         ...       ...             ...
# 47145       48216   32  single   m    bisexual    skinny        anything
# 47146       48217   24  single   m    straight       fit        anything
# 47147       48218   42  single   m    straight   average        anything
# 47148       48219   27  single   m    straight       fit        anything
# 47149       48220   39  single   m         gay   average  rather not say
#
#           drinks           drugs        education  ...  laugh    new  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47150 entries, 0 to 47149
# Data columns (total 53 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile_id       47150 non-null  int64
#  1   age              47150 non-null  int64
#  2   status           47150 non-null  object
#  3   sex              47150 non-null  object
#  4   orientation      47150 non-null  object
#  5   body_type        47150 non-null  object
#  6   diet             47150 non-null  object
#  7   drinks           47150 non-null  object
#  8   drugs            47150 non-null  object
#  9   education        47150 non-null  object
#  10  ethnicity        47150 non-null  object
#  11  height           47150 non-null  float64
#  12  income           47150 non-null  int64
#  13  job              47150 non-null  object
#  14  last_online      47150 non-null  object
#  15  offspring        47150 non-null  object
# ...

# %%
# export a df without the essay column but the 20 nw binary ones

# %%
df2=df.copy()

# %% [markdown]
# # drop all the essay columns

# %%
df2.drop(columns=['about_me','my_goals','my_talent','my_highlights','my_favorites','my_needs','think_about','typical_friday','my_secret','message_if'], inplace=True)

# %%
df3=df2.copy()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47150 entries, 0 to 47149
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile_id       47150 non-null  int64
#  1   age              47150 non-null  int64
#  2   status           47150 non-null  object
#  3   sex              47150 non-null  object
#  4   orientation      47150 non-null  object
#  5   body_type        47150 non-null  object
#  6   diet             47150 non-null  object
#  7   drinks           47150 non-null  object
#  8   drugs            47150 non-null  object
#  9   education        47150 non-null  object
#  10  ethnicity        47150 non-null  object
#  11  height           47150 non-null  float64
#  12  income           47150 non-null  int64
#  13  job              47150 non-null  object
#  14  last_online      47150 non-null  object
#  15  offspring        47150 non-null  object
# ...

# %%
# Count 'rather not say' values in each column
rather_not_say_counts = df3.apply(lambda x: (x == 'rather not say').sum())

print(rather_not_say_counts)
# Out:
# profile_id             0
# age                    0
# status                 0
# sex                    0
# orientation            0
# body_type              0
# diet               16689
# drinks              1281
# drugs              10432
# education           3149
# ethnicity           3319
# height                 0
# income                 0
# job                    0
# last_online            0
# offspring          32512
# pets               13610
# religion               0
# sign                   0
# smokes              3051
# speaks                 0
# city                   0
# ethnicity_count        0
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47150 entries, 0 to 47149
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   profile_id       47150 non-null  int64
#  1   age              47150 non-null  int64
#  2   status           47150 non-null  object
#  3   sex              47150 non-null  object
#  4   orientation      47150 non-null  object
#  5   body_type        47150 non-null  object
#  6   diet             47150 non-null  object
#  7   drinks           47150 non-null  object
#  8   drugs            47150 non-null  object
#  9   education        47150 non-null  object
#  10  ethnicity        47150 non-null  object
#  11  height           47150 non-null  float64
#  12  income           47150 non-null  int64
#  13  job              47150 non-null  object
#  14  last_online      47150 non-null  object
#  15  offspring        47150 non-null  object
# ...

# %%
okcupid_essaynormalized = df3

# Specify the folder path
folder_path = ('/Users/marina/Desktop/final_project/data/cleaned/')

# Specify the file name
file_name = 'okcupid_essaynormalized.csv'

 #Combine the folder path and file name
file_path = os.path.join(folder_path, file_name)

# Export the DataFrame to a CSV file
okcupid_essaynormalized.to_csv(file_path, index=False)

print(f'DataFrame exported to {file_path}')
# Out:
# DataFrame exported to /Users/marina/Desktop/final_project/data/cleaned/okcupid_essaynormalized.csv

# %% [markdown]
# # Create raw df for sql by table

# %%
# Create new DataFrames based on specified columns
profile_preferences = df3[['profile_id', 'orientation', 'religion', 'pets', 'offspring']]
profile_main = df3[['profile_id', 'age', 'status', 'orientation', 'body_type', 'sex', 'ethnicity', 'height', 'sign']]
profile_location = df3[['profile_id', 'city']]
profile_lastonline = df3[['profile_id', 'last_online']]
profile_habits = df3[['profile_id', 'diet', 'drinks', 'drugs', 'smokes']]
profile_qualifications = df3[['profile_id', 'job', 'education', 'speaks', 'income']]
profile_whatmatters = df3[['profile_id', 'love', 'fun', 'cooking', 'music', 'read', 'friends', 'work', 'travel', 'humor', 'movie', 'laugh', 'new', 'personality', 'future', 'people', 'smile', 'talk', 'life', 'tv', 'play']]

# Optional: Save the new DataFrames to CSV files
profile_preferences.to_csv('profile_preferences.csv', index=False)
profile_main.to_csv('profile_main.csv', index=False)
profile_location.to_csv('profile_location.csv', index=False)
profile_lastonline.to_csv('profile_lastonline.csv', index=False)
profile_habits.to_csv('profile_habits.csv', index=False)
profile_qualifications.to_csv('profile_qualifications.csv', index=False)
profile_whatmatters.to_csv('profile_whatmatters.csv', index=False)

# %%
# List of DataFrames and corresponding file names
dataframes = [
    profile_preferences,
    profile_main,
    profile_location,
    profile_lastonline,
    profile_habits,
    profile_qualifications,
    profile_whatmatters
]

file_names = [
    'profile_preferences.csv',
    'profile_main.csv',
    'profile_location.csv',
    'profile_lastonline.csv',
    'profile_habits.csv',
    'profile_qualifications.csv',
    'profile_whatmatters.csv'
]

# Specify the folder path
folder_path = '/Users/marina/Desktop/final_project/data/sql/raw'

# Save DataFrames to CSV files
for df, file_name in zip(dataframes, file_names):
    file_path = os.path.join(folder_path, file_name)
    df.to_csv(file_path, index=False)
    print(f'DataFrame exported to {file_path}')
# Out:
# DataFrame exported to /Users/marina/Desktop/final_project/data/sql/raw/profile_preferences.csv
# DataFrame exported to /Users/marina/Desktop/final_project/data/sql/raw/profile_main.csv
# DataFrame exported to /Users/marina/Desktop/final_project/data/sql/raw/profile_location.csv
# DataFrame exported to /Users/marina/Desktop/final_project/data/sql/raw/profile_lastonline.csv
# DataFrame exported to /Users/marina/Desktop/final_project/data/sql/raw/profile_habits.csv
# DataFrame exported to /Users/marina/Desktop/final_project/data/sql/raw/profile_qualifications.csv
# DataFrame exported to /Users/marina/Desktop/final_project/data/sql/raw/profile_whatmatters.csv

# %%
#/Users/marina/Desktop/final_project/data/sql/raw
